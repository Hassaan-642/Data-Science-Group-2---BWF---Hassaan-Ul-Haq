# %% [markdown]
# #Task 19

# %% [markdown]
# ##1. Linear Regression Plot (sns.regplot)

# %%
import seaborn as sns
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

df = pd.read_csv(r'C:\Users\Huawei\Downloads\university_enrollment.csv')
df1= pd.read_csv(r'C:\Users\Huawei\Downloads\flights.csv')


sns.regplot(x="pre_score", y="post_score", data=df)
# Out:
# <Axes: xlabel='pre_score', ylabel='post_score'>

# %% [markdown]
# ##2. Multiple Linear Regression Plot (sns.lmplot)

# %%
sns.lmplot(x="enrollment_count", y="pre_score", hue="post_score", data=df)

# %% [markdown]
# ##3. Residual Plot (sns.residplot)

# %%
sns.residplot(x="enrollment_count", y="pre_score", data=df)
# Out:
# <Axes: xlabel='enrollment_count', ylabel='pre_score'>

# %% [markdown]
# ##1. Histogram (sns.histplot)

# %%
sns.histplot(df["enrollment_count"], bins=30)
# Out:
# <Axes: xlabel='enrollment_count', ylabel='Count'>

# %% [markdown]
# ##2. Kernel Density Estimate (KDE) Plot (sns.kdeplot)

# %%
sns.kdeplot(df["pre_score"], shade=True)
# Out:
# <Axes: xlabel='pre_score', ylabel='Density'>

# %% [markdown]
# ##3. Distribution Plot (sns.distplot)

# %%
sns.distplot(df["post_score"], kde=True)
I
# Out:
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_12080\2456618079.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["post_score"], kde=True)
# <Axes: xlabel='post_score', ylabel='Density'>

# %% [markdown]
# ##4. Box Plot (sns.boxplot)

# %%
sns.boxplot(x="enrollment_count", y="post_score", data=df)
# Out:
# <Axes: xlabel='enrollment_count', ylabel='post_score'>

# %% [markdown]
# ##5. Violin Plot (sns.violinplot)

# %%
sns.violinplot(x="course_id", y="year", data=df)
# Out:
# <Axes: xlabel='course_id', ylabel='year'>

# %% [markdown]
# ##6. Pair Plot (sns.pairplot)

# %%
sns.pairplot(df)

# %% [markdown]
# ##1. Heatmap (sns.heatmap)

# %%
flights_pivot = df1.pivot(index="dep_time", columns="sched_dep_time", values="dep_delay")

sns.heatmap(flights_pivot, annot=True, fmt=".2f")
# Out:
# <Axes: xlabel='sched_dep_time', ylabel='dep_time'>

# %% [markdown]
# ##2. Joint Plot (sns.jointplot)

# %%
sns.jointplot(x="arr_time", y="sched_arr_time", data=df1, kind="scatter")

# %% [markdown]
# ##3. Facet Grid (sns.FacetGrid)

# %%
g = sns.FacetGrid(df1, col="arr_time", row="dep_time")
g.map(sns.scatterplot, "arr_time", "dep_time")
